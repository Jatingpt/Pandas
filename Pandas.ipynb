# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatingpt/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Pandas.**
# ##It is a library in Python where we can manipulate the data, can do the Data Modeling and EDA.

# %% [markdown]
# ##**Data Structure in Pandas-** There are two types of data in Pandas.
#
# ##1. Series- A series is a one-dimensional array capable of holding diffrent kind of datas(String, Float, Boolean, Integers etc.)
#
# ##2. Data Frame- Data Frame is two dimensional data which is in the form of row and columns.

# %% [markdown]
# ##**Creation of Data Frame in Pandas-**

# %%
import pandas as pd

# %%
data = {"Name": ["Rohan", "Rohit", "Aashish", "Tripti"],
        "Age": [23, 34, 32, 23],
        "Salary": [23000, 34000, 23000, 15000]}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Rohan   23   23000
# 1    Rohit   34   34000
# 2  Aashish   32   23000
# 3   Tripti   23   15000

# %% [markdown]
# Importing the data from different files.
#
# data = pd.read_csv("path")
#
# print(data)

# %%
data = pd.read_csv("/content/sample_data/california_housing_test.csv")
print(data)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %% [markdown]
# ##Using of different functions which are using duting EDA.
#
# ##E.g head, tail, describe, info, null values, duplicate values etc.

# %%
print(data.head(3))   #Top 3 values from the data.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0

# %%
print(data.tail(3))     #Last 3 values from the data.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# ##**Describe()** This function will provide the minimum, maximum, count, mean, standard deviation etc of all the integer values.

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %% [markdown]
# ##**Info()-** Info is used to get the total number of columns, rows including the null and not-null values etc.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ##**How to check null values.**

# %% [markdown]
# ##We can check the null values by using the "isnull" method. And also we can get the sum of null values by using the sum method.

# %%
print(data.isnull())
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# 0          False       False          False               False
# 1          False       False          False               False
# 2          False       False          False               False
# 3          False       False          False               False
# 4          False       False          False               False
# ...          ...         ...            ...                 ...
# 2995       False       False          False               False
# 2996       False       False          False               False
# 2997       False       False          False               False
# 2998       False       False          False               False
# 2999       False       False          False               False
#
# [3000 rows x 9 columns]

# %%
print(data.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# ##**How to handle duplicate values?**
#
# ##To handle duplicate values we can use the "duplicate" method, and also get the sum of duplicate values for better understanding.
#
#
# ##We can check the duplicates value in the whole data and also in particular columns.

# %%
data = pd.read_json("/content/sample_data/anscombe.json")
df = pd.DataFrame(data)
print(df)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# 42     IV   8   7.91
# 43     IV   8   6.89

# %%
df.columns
# Out:
# Index(['Series', 'X', 'Y'], dtype='object')

# %%
print(df["X"].duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40    False
# 41     True
# 42     True
# 43     True
# Name: X, dtype: bool

# %%
print(df["X"].duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40    False
# 41     True
# 42     True
# 43     True
# Name: X, dtype: bool

# %%
print(df["X"].duplicated().sum())
# Out:
# 32

# %% [markdown]
# ##**How to remove duplicates?**
#
# ##We can remove the duplicate values by using "drop_duplicates["Column Name"]",but before deleting anything we should ensure that we only have to remove or delete the values which is not needed as respect of our goals.
# ##we should not remove the duplicates from name, salary, gender, departments etc. Because they can be different persons instead remove customerId, EmployementId etc.

# %% [markdown]
# ##**How to deal with missing datas in Pandas?**
#
# ##Here, we are learning that which values should be delete, remove, replace and fill.
# ##Let's see how to replace string or integer values.

# %%
data = pd.read_json("/content/sample_data/anscombe.json")
df = pd.DataFrame(data)
print(df)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# 42     IV   8   7.91
# 43     IV   8   6.89

# %%
import pandas as pd

# %%
#creating a dataframe.
data = {"Name": ["Lalit", "Krishna", "Tushar", "Tulsi", "Khushi"],
        "Age": [23, 25, 25, 22, 30],
        "Salary": [23000, 32000, 28000, 29000, 30000]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary
# 0    Lalit   23   23000
# 1  Krishna   25   32000
# 2   Tushar   25   28000
# 3    Tulsi   22   29000
# 4   Khushi   30   30000

# %%
#To check the duplicated value.
df.duplicated("Age")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df["Age"].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
df["Age"].duplicated().sum()
# Out:
# 1

# %% [markdown]
# ##**Before drop or deleting any values of rows and columns.** It is only for checking but usually we should not delete the duplicates in Name, Age, Salary, Profession, Gender, Department because these things can be more than once instead we should delete everything from the primary key because a primary key should be always be unique.

# %%
#Droping the duplicated values.
df.drop_duplicates("Age")  #only to check the duplicate code.
# Out:
#       Name  Age  Salary
# 0    Lalit   23   23000
# 1  Krishna   25   32000
# 3    Tulsi   22   29000
# 4   Khushi   30   30000

# %% [markdown]
# ##**Working or dealing with missing data.**

# %%
data = {"Name": ["Lalit", "Krishna", "Tushar", None, "Khushi"],
        "Age": [23, 25, 25, 22, 30],
        "Salary": [23000, 32000, 28000, 29000, 30000]}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary
# 0    Lalit   23   23000
# 1  Krishna   25   32000
# 2   Tushar   25   28000
# 3     None   22   29000
# 4   Khushi   30   30000

# %%
df.isnull()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3   True  False   False
# 4  False  False   False

# %%
import numpy as np
df.replace(np.nan, "Tulsi")
# Out:
#       Name  Age  Salary
# 0    Lalit   23   23000
# 1  Krishna   25   32000
# 2   Tushar   25   28000
# 3    Tulsi   22   29000
# 4   Khushi   30   30000

# %%
data = {"Emp_id": ["ID1", "ID2", "ID3", "ID3", "ID4", "ID5"],
        "Name": ["Lalit", "Krishna", None, None, "Khushi", "Hasina"],
        "Age": [23, 25, 25, 22, 30, 29],
        "Salary": [23000, 32000, 28000, 29000, 30000, 29000]}

df = pd.DataFrame(data)
df
# Out:
#   Emp_id     Name  Age  Salary
# 0    ID1    Lalit   23   23000
# 1    ID2  Krishna   25   32000
# 2    ID3     None   25   28000
# 3    ID3     None   22   29000
# 4    ID4   Khushi   30   30000
# 5    ID5   Hasina   29   29000

# %%
#filling the data using backword fill and forward fill.
df.isnull().sum()
# Out:
# Emp_id    0
# Name      2
# Age       0
# Salary    0
# dtype: int64

# %%
df.fillna(method = "bfill")
# Out:
# <ipython-input-34-e2857e059804>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill")
#   Emp_id     Name  Age  Salary
# 0    ID1    Lalit   23   23000
# 1    ID2  Krishna   25   32000
# 2    ID3   Khushi   25   28000
# 3    ID3   Khushi   22   29000
# 4    ID4   Khushi   30   30000
# 5    ID5   Hasina   29   29000

# %%
df.duplicated("Emp_id")   #as we can see that there are one duplicate values in our primary key which should be delete.

#dropping the duplicate values from id columns.

new_df = df.drop_duplicates("Emp_id")
new_df
# Out:
#   Emp_id     Name  Age  Salary
# 0    ID1    Lalit   23   23000
# 1    ID2  Krishna   25   32000
# 2    ID3     None   25   28000
# 4    ID4   Khushi   30   30000
# 5    ID5   Hasina   29   29000

# %%
#Column transformation.
data = {"Emp_id": ["ID1", "ID2", "ID3", "ID3", "ID4", "ID5"],
        "Name": ["Lalit", "Krishna", "Sohan", "Punit", "Khushi", "Hasina"],
        "Age": [23, 25, 25, 22, 30, 29],
        "Salary": [23000, 32000, 28000, 29000, 30000, 29000]}

df = pd.DataFrame(data)
df
# Out:
#   Emp_id     Name  Age  Salary
# 0    ID1    Lalit   23   23000
# 1    ID2  Krishna   25   32000
# 2    ID3    Sohan   25   28000
# 3    ID3    Punit   22   29000
# 4    ID4   Khushi   30   30000
# 5    ID5   Hasina   29   29000

# %%
df.loc[(df["Salary"] < 25000), ["BONUS"] == "10% Bonus"
# Out:
#   File "<ipython-input-43-901c79d825a6>", line 1
#     df.loc[(df["Salary"] < 25000), ["BONUS"] == "10% Bonus"
#                                                            ^
# SyntaxError: incomplete input
